# %% [markdown]
# # Tests for NN from scratch

# %%
from SimpleNNfirstattempt import NeuralNetwork
import numpy as np
import sklearn.datasets  as datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## XOR gate

# %% [markdown]
# The most simple test to see if a neural network is working is the XOR gate detailed below.

# %%
XOR_Gate = NeuralNetwork()

XOR_Gate.add_input(2)
XOR_Gate.add_dense(3, activation_function = False)
XOR_Gate.add_output(1)

# %%
x = np.array([    [0,0],[0,1],[1,0] ,[1,1]    ])

y = np.array(    [[0],[1],[1],[0]])

XOR_Gate.train(x, y, epoches = 100000, learn_rate= 0.1)

print( XOR_Gate.predict(x) )
# Out:
# [[0.07435505]
#  [0.29332751]
#  [0.35315525]
#  [0.65327135]]

# %% [markdown]
# ## Circular data

# %%
circularX, circulary = datasets.make_circles(n_samples = 500, random_state = 42)

circularX_train, circularX_test, circulary_train, circulary_test = train_test_split(circularX, circulary, random_state = 42, train_size = 0.1)


circularNN = NeuralNetwork()

circularNN.add_input(2)
circularNN.add_dense(6)
circularNN.add_dense(6)
circularNN.add_output(1)

circularNN.train(circularX_train, circulary_train.reshape(-1, 1), epoches = 5000, learn_rate = 0.001, print_information = True)
pred = circularNN.predict(circularX_test)

print(pred)
pred_binary = (pred > 0.5).astype(int)


plt.figure(figsize=(8, 6))
plt.scatter(circularX_test[pred_binary.flatten() == 1][:, 0], circularX_test[pred_binary.flatten() == 1][:, 1], color='red', label='Class 1', edgecolor='k')
plt.title('Circular Classification Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Network converged! Training finished
# Converged on a training cost of [3.6336256] in 2369 epoches
# [[0.19303289]
#  [0.19324419]
#  [0.19315013]
#  [0.27117254]
#  [0.62115404]
#  [0.18897261]
#  [1.13278324]
#  [0.65221436]
#  [0.97498606]
#  [1.10762567]
#  [0.22252477]
#  [0.23800227]
#  [0.18647507]
#  [0.32661301]
#  [0.26866786]
#  [0.74264413]
#  [0.30364887]
#  [0.41793646]
#  [0.54034873]
#  [0.17738307]
#  [0.52250728]
#  [0.72230072]
#  [0.18744173]
#  [0.53239384]
#  [0.17584539]
#  [0.20762662]
#  [0.6439656 ]
#  [0.43286383]
#  [0.13186952]
#  [0.34426679]
#  [0.49486944]
#  [0.81524204]
#  [0.88351096]
#  [0.38786366]
#  [0.57642165]
#  [0.21707708]
#  [0.28050925]
#  [0.48869079]
#  [0.23800227]
#  [0.60878892]
#  [0.29149434]
#  [0.40782346]
#  [0.85240017]
#  [1.1059796 ]
#  [0.27871541]
#  [0.25650795]
#  [0.23800227]
#  [0.22336664]
#  [0.17918612]
#  [0.18973672]
#  [0.18722397]
#  [0.6936937 ]
#  [0.23800227]
#  [0.60436796]
#  [0.18159446]
#  [0.21231626]
#  [0.30316499]
#  [0.19161293]
#  [0.54751885]
#  [0.25202703]
#  [0.32418056]
#  [0.3621875 ]
#  [0.27789274]
#  [0.67095993]
#  [0.29971398]
#  [0.19811774]
#  [0.21370395]
#  [0.83820687]
#  [0.89884925]
#  [0.32388044]
#  [0.66749769]
#  [1.06241724]
#  [0.87165945]
#  [0.36856778]
#  [0.26147438]
#  [1.07572704]
#  [0.62925344]
#  [0.94163804]
#  [0.25940789]
#  [0.62143213]
#  [0.28712734]
#  [0.44268638]
#  [0.44692867]
#  [0.82658591]
#  [0.23473349]
#  [0.80071322]
#  [0.95812168]
#  [0.18779307]
#  [0.73538351]
#  [0.1920477 ]
#  [0.43044021]
#  [0.1968583 ]
#  [0.36928349]
#  [0.19374942]
#  [0.97469223]
#  [0.31503705]
#  [0.14460201]
#  [0.18543634]
#  [0.26488901]
#  [0.5176828 ]
#  [0.18915642]
#  [0.11709202]
#  [0.86166817]
#  [0.54770155]
#  [0.1762079 ]
#  [0.24041046]
#  [0.21500236]
#  [0.79339298]
#  [0.5420447 ]
#  [0.79616944]
#  [0.19317669]
#  [0.51539277]
#  [0.25324524]
#  [0.19251678]
#  [0.62250949]
#  [0.23800227]
#  [0.17682315]
#  [0.21732815]
#  [0.69864502]
#  [0.39818763]
#  [0.6996898 ]
#  [0.79868948]
#  [0.56856671]
#  [0.87369148]
#  [0.57113336]
#  [0.57985516]
#  [0.50082235]
#  [0.13227931]
#  [0.20581273]
#  [1.00261834]
#  [0.97193114]
#  [0.12471888]
#  [0.1904267 ]
#  [0.43413826]
#  [0.1910421 ]
#  [1.14665667]
#  [0.26283391]
#  [0.74918869]
#  [0.29543811]
#  [0.3322678 ]
#  [0.22292461]
#  [0.57731257]
#  [0.21593848]
#  [0.19158255]
#  [0.18025851]
#  [0.23800227]
#  [0.22138671]
#  [0.37356407]
#  [0.22345268]
#  [0.41679068]
#  [0.94467631]
#  [0.21622794]
#  [0.26568709]
#  [0.46176653]
#  [0.20407138]
#  [0.65096966]
#  [0.64718614]
#  [0.57388252]
#  [0.22314432]
#  [0.46975077]
#  [0.88523573]
#  [0.6460959 ]
#  [0.18405857]
#  [0.68237016]
#  [0.1119825 ]
#  [0.90743583]
#  [0.50557173]
#  [0.20018343]
#  [1.04110561]
#  [0.95625184]
#  [0.11709322]
#  [0.16177382]
#  [0.56267762]
#  [0.37909833]
#  [0.19117415]
#  [0.38135972]
#  [0.42724996]
#  [0.99544334]
#  [0.49487184]
#  [0.87977324]
#  [1.07663101]
#  [0.22250913]
#  [0.18990338]
#  [0.71549884]
#  [0.13976972]
#  [0.85320904]
#  [0.41040299]
#  [0.26683425]
#  [0.35585358]
#  [0.15452163]
#  [0.76720893]
#  [1.11307844]
#  [0.30961292]
#  [1.01672145]
#  [0.34788167]
#  [0.35570562]
#  [0.23800227]
#  [0.19298864]
#  [0.64647096]
#  [0.20721505]
#  [0.62662269]
#  [0.19971145]
#  [0.38077567]
#  [0.20927664]
#  [0.74321799]
#  [0.83360449]
#  [0.22273661]
#  [0.78922058]
#  [0.79620142]
#  [0.59347018]
#  [0.29957353]
#  [0.4699024 ]
#  [0.71078788]
#  [0.87418215]
#  [1.04645871]
#  [0.27303099]
#  [0.65541768]
#  [0.79574943]
#  [0.69957615]
#  [0.21621068]
#  [0.29165555]
#  [0.87069769]
#  [0.77407733]
#  [0.42569363]
#  [0.17773029]
#  [0.16355206]
#  [0.17862276]
#  [0.19169716]
#  [0.36425449]
#  [0.26801032]
#  [0.51883588]
#  [0.55248028]
#  [0.56709395]
#  [0.72489698]
#  [0.24545784]
#  [0.14100755]
#  [0.51676415]
#  [0.1921448 ]
#  [0.90249365]
#  [0.47775449]
#  [0.20326924]
#  [0.21084018]
#  [0.56285292]
#  [0.22346375]
#  [0.39188389]
#  [0.94441134]
#  [0.23800227]
#  [0.20890159]
#  [0.97417969]
#  [0.79604917]
#  [0.26492595]
#  [0.7536875 ]
#  [0.81494669]
#  [0.22196814]
#  [0.17424234]
#  [0.37895945]
#  [0.86238637]
#  [0.89797196]
#  [0.92488528]
#  [0.22337938]
#  [1.06322683]
#  [0.13139996]
#  [0.75719169]
#  [0.19243725]
#  [0.17461993]
#  [0.21922893]
#  [0.1843262 ]
#  [0.21470919]
#  [0.15053963]
#  [0.20547654]
#  [1.12658414]
#  [0.41126717]
#  [0.89346288]
#  [0.4348261 ]]
